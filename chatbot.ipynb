# %%
import pandas as pd 
# %pip install datasets
# Out:
# ...
#   Obtaining dependency information for datasets from https://files.pythonhosted.org/packages/e2/cf/db41e572d7ed958e8679018f8190438ef700aeb501b62da9e1eed9e4d69a/datasets-2.15.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pyarrow>=8.0.0 from https://files.pythonhosted.org/packages/43/3f/7bdf7dc3b3b0cfdcc60760e7880954ba99ccd0bc1e0df806f3dd61bc01cd/pyarrow-14.0.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pyarrow-hotfix from https://files.pythonhosted.org/packages/e4/f4/9ec2222f5f5f8ea04f66f184caafd991a39c8782e31f5b0266f101cb68ca/pyarrow_hotfix-0.6-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dill<0.3.8,>=0.3.0 from https://files.pythonhosted.org/packages/f5/3a/74a29b11cf2cdfcd6ba89c0cecd70b37cd1ba7b77978ce611eb7a146a832/dill-0.3.7-py3-none-any.whl.metadata
# ...

# %%
data_path =pd.read_csv('dataset.csv') 
data.columns
# Out:
# Index(['Вопрос ', 'Ответ', 'Unnamed: 2'], dtype='object')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


dataset_path = 'dataset.csv'
df = pd.read_csv(dataset_path)


corpus = df['Вопрос '].tolist()  
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(corpus)


def get_best_response(query, tfidf_matrix, corpus):
    query_vector = vectorizer.transform([query])
    similarity_scores = cosine_similarity(query_vector, tfidf_matrix)
    best_index = similarity_scores.argmax()
    best_response = df.loc[best_index, 'Ответ']  
    return best_response


user_query = "Какое твое любимое блюдо"
response = get_best_response(user_query, tfidf_matrix, corpus)
print(response)
# Out:
# Ножки в чулочках!

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import nltk
import spacy
from nltk.corpus import stopwords
import pymorphy2
import random

nltk.download('stopwords')

def obfuscate_code():
    def func1(x):
        return [float(elem) if isinstance(elem, (int, float)) else elem for elem in x]

    def func2(x):
        return [float(elem) + random.uniform(-1.0, 1.0) if isinstance(elem, (int, float)) else elem for elem in x]

    return func1, func2

# Измененные названия для функций предобработки и векторизации
preprocess_input_obfuscated, vectorize_input_obfuscated = obfuscate_code()

def postprocess_output(output_tensor):
    labels = answers[:]  # Вам нужно определить переменную answers

    _, predicted_index = torch.max(output_tensor, dim=1)
    output_label = labels[predicted_index.item()]
    return output_label

class Ciphertext(nn.Module):
    def __init__(self, x_dim, h_dim, y_dim, n_layers, n_heads, drop):
        super(Ciphertext, self).__init__()
        self.obfuscated_name = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(x_dim, n_heads, h_dim, drop),
            n_layers)
        self.hidden_layer = nn.Linear(h_dim, y_dim)

    def forward(self, x):
        x = self.obfuscated_name(x)
        x = self.hidden_layer(x)
        return x

num_epochs = 3 
batch_size = 1 

user_input = input("Введите ваш запрос: ")
processed_input_obfuscated = preprocess_input_obfuscated(user_input)
vectorized_input_obfuscated = vectorize_input_obfuscated(processed_input_obfuscated)

# Преобразование в числа только если элемент не является строкой
input_tensor = torch.tensor(vectorized_input_obfuscated, dtype=torch.float).unsqueeze(0)

x_dim = len(vectorized_input_obfuscated) 
h_dim = len(vectorized_input_obfuscated) 
y_dim = len(vectorized_input_obfuscated)
n_layers = 4 
n_heads = 1
drop = 0.2 

model = Ciphertext(x_dim, h_dim, y_dim, n_layers, n_heads, drop)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(num_epochs):
    running_loss = 0.0
    
    output_tensor = model(input_tensor)
    optimizer.zero_grad()
    
    output = postprocess_output(output_tensor)
   
    print("Ответ: ", output)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fobus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 52
#      49 vectorized_input_obfuscated = vectorize_input_obfuscated(processed_input_obfuscated)
#      51 # Преобразование в числа только если элемент не является строкой
# ---> 52 input_tensor = torch.tensor(vectorized_input_obfuscated, dtype=torch.float).unsqueeze(0)
#      54 x_dim = len(vectorized_input_obfuscated)
#      55 h_dim = len(vectorized_input_obfuscated)
#
# ValueError: too many dimensions 'str'

# %% [markdown]
# Не понимаю почему так ((((((
